# %%
new_car_id = [
    ["13-04-2025", "Sunday",    [4, 6, 7, 8, 1]],
    ["14-04-2025", "Monday",    [2, 1, 8, 6, 4]],
    ["15-04-2025", "Tuesday",   [3, 1, 6, 6, 4]],
    ["16-04-2025", "Wednesday", [1, 6, 9, 8, 3]],
    ["17-04-2025", "Thursday",  [4, 7, 7, 10, 1]]
]
renew_car_id = [
    ["13-04-2025", "Sunday",    [4, 9, 7, 7, 1]],
    ["14-04-2025", "Monday",    [3, 1, 7, 7, 3]],
    ["15-04-2025", "Tuesday",   [3, 5, 9, 10, 2]],
    ["16-04-2025", "Wednesday", [3, 6, 6, 9, 1]],
    ["17-04-2025", "Thursday",  [1, 2, 9, 8, 4]]
]

new_driving_license = [
    ["13-04-2025", "Sunday",    [2, 4, 9, 6, 2]],
    ["14-04-2025", "Monday",    [2, 6, 8, 8, 1]],
    ["15-04-2025", "Tuesday",   [4, 5, 6, 8, 2]],
    ["16-04-2025", "Wednesday", [3, 10, 6, 10, 1]],
    ["17-04-2025", "Thursday",  [2, 5, 10, 6, 2]]
]

renew_driving_license = [
    ["13-04-2025", "Sunday",    [2, 6, 10, 8, 4]],
    ["14-04-2025", "Monday",    [1, 3, 7, 7, 4]],
    ["15-04-2025", "Tuesday",   [2, 6, 10, 6, 1]],
    ["16-04-2025", "Wednesday", [2, 10, 7, 8, 1]],
    ["17-04-2025", "Thursday",  [2, 7, 7, 7, 1]]
]

lost_id = [
    ["13-04-2025", "Sunday",    [1, 3, 9, 8, 3]],
    ["14-04-2025", "Monday",    [3, 9, 6, 6, 4]],
    ["15-04-2025", "Tuesday",   [4, 7, 8, 7, 3]],
    ["16-04-2025", "Wednesday", [3, 9, 6, 9, 4]],
    ["17-04-2025", "Thursday",  [2, 4, 10, 7, 1]]
]

all_reservations = [num for day in new_car_id for num in day[2]]
count=25
sums=0
for i in all_reservations:
  sums+=i
The_mean_of_new_car_id = sums/count

def most_crowded(survicex):
    total_reservations_each_day = []
    days = []
    for day_data in survicex:
        total = 0
        for j in day_data[2]:
          total+=j
        total_reservations_each_day.append(total)
        days.append(day_data[1])

    max_index = total_reservations_each_day.index(max(total_reservations_each_day))
    return days[max_index]

def least_crowded(survicex):
    total_reservations_each_day = []
    days=[]
    for day_data in survicex:
        total = 0
        for j in day_data[2]:
          total+=j
        total_reservations_each_day.append(total)
        days.append(day_data[1])

    min_index = total_reservations_each_day.index(min(total_reservations_each_day))
    return days[min_index]

print(f"The average of reservations for new car id service = {The_mean_of_new_car_id}")
print(f"The most crowded day in new car id service is: {most_crowded(new_car_id)}")
print(f"The least crowded day in new car id service is: {least_crowded(new_car_id)}")
print(f"The most crowded day in renew car id service is: {most_crowded(renew_car_id)}")
print(f"The least crowded day in renew car id service is: {least_crowded(renew_car_id)}")
print("Welcome to our Booking System")
services_arabic = [
    'اصدار رخصة سيارة اول مرة',
    'تجديد رخصة سيارة',
    'اصدار رخصة قيادة اول مرة',
    'تجديد رخصة قيادة',
    'اصدار بدل فاقد'
]
services=[ [
    ["13-04-2025", "Sunday",    [4, 6, 7, 8, 1]],
    ["14-04-2025", "Monday",    [2, 1, 8, 6, 4]],
    ["15-04-2025", "Tuesday",   [3, 1, 6, 6, 4]],
    ["16-04-2025", "Wednesday", [1, 6, 9, 8, 3]],
    ["17-04-2025", "Thursday",  [4, 7, 7, 10, 1]]
],
 [
    ["13-04-2025", "Sunday",    [4, 9, 7, 7, 1]],
    ["14-04-2025", "Monday",    [3, 1, 7, 7, 3]],
    ["15-04-2025", "Tuesday",   [3, 5, 9, 10, 2]],
    ["16-04-2025", "Wednesday", [3, 6, 6, 9, 1]],
    ["17-04-2025", "Thursday",  [1, 2, 9, 8, 4]]
],

 [
    ["13-04-2025", "Sunday",    [2, 4, 9, 6, 2]],
    ["14-04-2025", "Monday",    [2, 6, 8, 8, 1]],
    ["15-04-2025", "Tuesday",   [4, 5, 6, 8, 2]],
    ["16-04-2025", "Wednesday", [3, 10, 6, 10, 1]],
    ["17-04-2025", "Thursday",  [2, 5, 10, 6, 2]]
],

 [
    ["13-04-2025", "Sunday",    [2, 6, 10, 8, 4]],
    ["14-04-2025", "Monday",    [1, 3, 7, 7, 4]],
    ["15-04-2025", "Tuesday",   [2, 6, 10, 6, 1]],
    ["16-04-2025", "Wednesday", [2, 10, 7, 8, 1]],
    ["17-04-2025", "Thursday",  [2, 7, 7, 7, 1]]
],

 [
    ["13-04-2025", "Sunday",    [1, 3, 9, 8, 3]],
    ["14-04-2025", "Monday",    [3, 9, 6, 6, 4]],
    ["15-04-2025", "Tuesday",   [4, 7, 8, 7, 3]],
    ["16-04-2025", "Wednesday", [3, 9, 6, 9, 4]],
    ["17-04-2025", "Thursday",  [2, 4, 10, 7, 1]]
]]
slots=["at 9 AM", "at 10 AM", "at 11 AM", "at 12 PM", "at 1 PM"]
username="***"
password="***"
while True:
    decision=input("Do you want to sign up or log in? ")
    if decision == "sign up":
        username = input("Enter a username: ")
        print("*****Password must be Exactly 8 characters, no digits or simbols, and a mix of capital and small letters*****")
        while True:
            password=input("Enter a password: ")

            if len(password) != 8:
                print("Error: Password must be exactly 8 characters!")
                continue
            if not password.isalpha():
              print("Error: Password must contain only alphabitical letters!")
              continue

            if not (any(c.isupper() for c in password)) or not (any(c.islower() for c in password)):
                print("Error: Password must contain both capital and small letters!")
                continue

            confirming_pass = input("Confirm password: ")
            if password == confirming_pass:
                print("Successful registration!")
                break
            else:
                print("Error: Passwords don't match! Please try again.")

    elif decision == "log in"and username=="***":
      print("You have not rigestered before, please choose to sign up first!")

      continue


    elif decision == "log in"and username!="***":
       print("Please log in!")
       f=0
       t=True
       while True:
         if f==0 or t==False:
           input_username=input("Enter your username: ")
           t=True
         input_password=input("Enter your password: ")
         if input_username!=username:
            print( "Incorrect username!")
            f+=1
            t=False
         elif input_password!=password:
          print( "Incorrect password!")
         else:
          print(f"Welcome, {username}!")
          break

       name=input("Enter your full name: ")
       ID=input("Enter your ID number: ")
       print("Our services: ")
       print("1- اصدار رخصة سيارة اول مرة")
       print("2- تجديد رخصة سيارة")
       print("3- اصدار رخصة قيادة اول مرة")
       print("4- تجديد رخصة قيادة")
       print("5- اصدار بدل فاقد")

       service=int(input("Choose a service from 1 to 5:- "))
       print("Available working days: ")
       print("1- Sunday")
       print("2- Monday")
       print("3- Tuesday")
       print("4- Wednesday")
       print("5- Thursday")
       day= int(input("Choose a day from 1 to 5:- "))
       print(" The available time slots and the number of remaining places: ")

       if services[service-1][day-1][2][0]<10:
         print(" 1- at 9 AM :")
         print(10-services[service-1][day-1][2][0])
       if services[service-1][day-1][2][1]<10:
         print(" 2- at 10 AM :")
         print(10-services[service-1][day-1][2][1])
       if services[service-1][day-1][2][2]<10:
         print(" 3- at 11 AM :")
         print(10-services[service-1][day-1][2][2])
       if services[service-1][day-1][2][3]<10:
         print(" 4- at 12 PM :")
         print(10-services[service-1][day-1][2][3])
       if services[service-1][day-1][2][4]<10:
         print(" 5- at 1 PM :")
         print(10-services[service-1][day-1][2][4])

       slot=int(input("Choose a time slot from 1 to 5: "))
       print("Confirmation: ")
       print(f"full name: {name}")
       print(f"ID: {ID}")
       print(f"Service: {services_arabic[service-1]}")
       print(f"The chosen date: {services[service-1][day-1][0]}")
       print(f"The chosen day: {services[service-1][day-1][1]}")

       print(f"The chosen time slot: {slots[slot-1]}")
       break



    else:
        print("Invalid choice. Please choose to sign up or log in!")
# Out:
# The average of reservations for new car id service = 4.92
# The most crowded day in new car id service is: Thursday
# The least crowded day in new car id service is: Tuesday
# The most crowded day in renew car id service is: Tuesday
# The least crowded day in renew car id service is: Monday
# Welcome to our Booking System
# Do you want to sign up or log in? sign up
# Enter a username: rana
# *****Password must be Exactly 8 characters, no digits or simbols, and a mix of capital and small letters*****
# Enter a password: Ranastem
# Confirm password: Ranastem
# Successful registration!
# Do you want to sign up or log in? log in
# Please log in!
# Enter your username: rana
# Enter your password: Ranastem
# Welcome, rana!
# Enter your full name: rf
# Enter your ID number: 78687
# Our services:
# 1- اصدار رخصة سيارة اول مرة
# 2- تجديد رخصة سيارة
# 3- اصدار رخصة قيادة اول مرة
# 4- تجديد رخصة قيادة
# 5- اصدار بدل فاقد
# Choose a service from 1 to 5:- 4
# Available working days:
# 1- Sunday
# ...
